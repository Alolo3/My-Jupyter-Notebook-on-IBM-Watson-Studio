# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <a href="http://url" target="_blank" rel="noopener noreferrer">link getting-confused-at-this-point</a>

# %% [markdown]
# #My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Arimeyaw Alhassan Alolo**
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because it offers the opportunity for one to play with data to unearth its untold stories. Additionally, due to the fact that I enjoy analyzing issues to understand in totality what the issues are, data science will provide me with the necessary tools, techniques and knowledge to be able to perform an informed analysis for better decision making.*

# %% [markdown]
# ###The code below assigns number 5 to letter a and number 6 to letter b. The results of adding a and b is stored assigned to x and printed.

# %%
a = 5
b = 6
x = a + b

print(x)
# Out:
# 11

# %% [markdown]
# > This is getting interesting
# > and I am loving it already.
# > Will pursue to the end
#
# - Red
# - Gold
# - Green
#
# 1. Red means STOP
# 1. Gold means 'get ready'
# 1. Green means 'Go and Go and Gooooooooooooo'
#
# | Name | Age | Gender |
# | --- | --- | --- |
# | Alolo | 40 | Male |
# ![licensed-image.jpeg](attachment:c31a13ba-f87a-4e42-9320-0412132b45c3.jpeg)
#
# `trying my hands`
#
# ```
#
# trying my hands
#
# ```
#
# > something nice is happening
#
# >> and I am enjoying it
#
# >>> believe me
#
#
# ~~my thing is working~~
